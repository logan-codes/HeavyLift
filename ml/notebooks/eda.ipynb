# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv(r"E:\Coding\HeavyLift\ml\data\process\combined_data.csv")
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8688 entries, 0 to 8687
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SERIAL NUMBER      6394 non-null   float64
#  1   EQU.TYPE           5472 non-null   str
#  2   EQU.MODEL          5472 non-null   str
#  3   SHIFT              5472 non-null   str
#  4   DATE               5472 non-null   str
#  5   NUM OF HOURS       5472 non-null   float64
#  6   RENTAL COST        5472 non-null   float64
#  7   DESIELCONSUMPTION  5472 non-null   float64
#  8   DESIEL COST        8688 non-null   float64
#  9   TOTAL COST         8688 non-null   float64
#  10  BREAK DOWN HOURS   5472 non-null   float64
#  11  DAY                5472 non-null   str
#  12  DRIVER             5472 non-null   str
#  13  month              8688 non-null   str
#  14  TOTAL COST2        0 non-null      float64
# dtypes: float64(8), str(7)
# memory usage: 1018.3 KB

# %%
corr_matrix = df.corr(numeric_only=True)

# Focus on correlation with Churn
churn_corr = corr_matrix[['DESIEL COST']].sort_values(by='DESIEL COST', ascending=False)

# Plot heatmap
plt.figure(figsize=(4, 12))
sns.heatmap(churn_corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation of Features with Churn')
plt.show()
