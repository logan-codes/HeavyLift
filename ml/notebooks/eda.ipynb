# %%
import pandas as pd
import seaborn as sns
import matplotlib

# %%
df= pd.read_csv(r"E:\Coding\HeavyLift\ml\data\process\combined_data.csv")
df.describe
# Out:
# <bound method NDFrame.describe of       SERIAL NUMBER   EQU.TYPE EQU.MODEL  SHIFT        DATE  NUM OF HOURS  \
# 0               1.0  EXCAVATOR   CAT 300    DAY  2022-02-01           8.0
# 1               2.0  EXCAVATOR   CAT 300    DAY  2022-02-02           8.0
# 2               3.0  EXCAVATOR   CAT 300    DAY  2022-02-03           6.0
# 3               4.0  EXCAVATOR   CAT 300    DAY  2022-02-05           8.0
# 4               5.0  EXCAVATOR   CAT 300    DAY  2022-02-06           8.0
# ...             ...        ...       ...    ...         ...           ...
# 8683          908.0     LOADER        L6  NIGHT  2022-07-20           6.0
# 8684          909.0     LOADER        L6  NIGHT  2022-07-21           8.0
# 8685          910.0     LOADER        L6  NIGHT  2022-07-22           6.0
# 8686          911.0     LOADER        L6  NIGHT  2022-07-23           8.0
# 8687          912.0     LOADER        L6  NIGHT  2022-07-24           7.0
#
# ...

# %%
corr = pd.corr(df)
